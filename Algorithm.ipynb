# %%
from extraction_functions import *
from line_separation import *

# %% [markdown]
# # Load a test image

# %%
img = (my_imread_gray('tests/test_6.jpg') * 255).astype(np.uint8)

# %% [markdown]
# # Fix orientation & skew

# %%
img_orientation_fix = fix_skew_and_rotation(img)
my_show_images([img, img_orientation_fix], ['original', 'orientation & skew fix'], row_max=2)
# Out:
# 1773
# 2308

# %% [markdown]
# # Extract individual lines

# %% [markdown]
# #### Binarization

# %%
img_binary_bg_white = img_orientation_fix > 200
my_show_images([img_binary_bg_white])

# %% [markdown]
# #### Extraction

# %%
distance_between_staves = get_distance_between_staves(img_binary_bg_white)
lines = get_sperated_lines(img_binary_bg_white, distance_between_staves)

# %%
my_show_images(lines, dpi=50)
